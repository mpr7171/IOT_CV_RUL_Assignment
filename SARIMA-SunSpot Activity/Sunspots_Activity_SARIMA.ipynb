# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.api import qqplot

# %%
dta = pd.read_csv("/content/drive/MyDrive/sunspots.csv")
dta.index = pd.Index(sm.tsa.datetools.dates_from_range('1700', '2008'))
del dta["YEAR"]

# %%
dta.head(10)
# Out:
#             SUNACTIVITY
# 1700-12-31          5.0
# 1701-12-31         11.0
# 1702-12-31         16.0
# 1703-12-31         23.0
# 1704-12-31         36.0
# 1705-12-31         58.0
# 1706-12-31         29.0
# 1707-12-31         20.0
# 1708-12-31         10.0
# 1709-12-31          8.0

# %%
dta.describe()
# Out:
#        SUNACTIVITY
# count   309.000000
# mean     49.752104
# std      40.452595
# min       0.000000
# 25%      16.000000
# 50%      40.000000
# 75%      69.800000
# max     190.200000

# %%
print(sm.datasets.sunspots.NOTE)
# Out:
# ::
#
#     Number of Observations - 309 (Annual 1700 - 2008)
#     Number of Variables - 1
#     Variable name definitions::
#
#         SUNACTIVITY - Number of sunspots for each year
#
#     The data file contains a 'YEAR' variable that is not returned by load.

# %%
dta
# Out:
#             SUNACTIVITY
# 1700-12-31          5.0
# 1701-12-31         11.0
# 1702-12-31         16.0
# 1703-12-31         23.0
# 1704-12-31         36.0
# ...                 ...
# 2004-12-31         40.4
# 2005-12-31         29.8
# 2006-12-31         15.2
# 2007-12-31          7.5
# 2008-12-31          2.9
#
# [309 rows x 1 columns]

# %%
dta.plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(dta.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(dta, lags=40, ax=ax2)

# %%
sarima_mod = SARIMAX(dta, order=(2, 0, 0), seasonal_order=(1, 0, 1, 12)).fit()
print(sarima_mod.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency A-DEC will be used.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          SUNACTIVITY   No. Observations:                  309
# Model:             SARIMAX(2, 0, 0)x(1, 0, [1], 12)   Log Likelihood               -1327.771
# Date:                              Sun, 15 Oct 2023   AIC                           2665.543
# Time:                                      17:23:31   BIC                           2684.210
# Sample:                                  12-31-1700   HQIC                          2673.006
#                                        - 12-31-2008
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.3874      0.037     37.730      0.000       1.315       1.459
# ar.L2         -0.6570      0.036    -18.077      0.000      -0.728      -0.586
# ar.S.L12       0.9992      0.005    184.689      0.000       0.989       1.010
# ma.S.L12      -0.9688      0.105     -9.266      0.000      -1.174      -0.764
# sigma2       288.4109     30.832      9.354      0.000     227.982     348.840
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.41   Jarque-Bera (JB):                52.67
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.69   Skew:                             0.58
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(sarima_mod.aic, sarima_mod.bic, sarima_mod.hqic)
# Out:
# 2665.5428669897783 2684.209573374267 2673.0058517963357

# %%
sarima_mod.plot_diagnostics(figsize=(10, 8))
plt.show()

# %%
predict_sunspots_sarima = sarima_mod.predict('1990', '2012', dynamic=False)

# %%
ax = dta.loc['1950':].plot(figsize=(12, 8))
ax = predict_sunspots_sarima.plot(ax=ax, style='r--', label='SARIMA Prediction')
ax.legend()
ax.axis((-20.0, 38.0, -4.0, 200.0))
# Out:
# (-20.0, 38.0, -4.0, 200.0)

# %%
def mean_forecast_err(y, yhat):
    return y.sub(yhat).mean()

def mean_absolute_err(y, yhat):
    return np.mean((np.abs(y.sub(yhat).mean()) / yhat))

# %%
print("MFE = ", mean_forecast_err(dta.SUNACTIVITY, predict_sunspots_sarima))
print("MAE = ", mean_absolute_err(dta.SUNACTIVITY, predict_sunspots_sarima))
# Out:
# MFE =  0.8253999097111656
# MAE =  0.030125298196362435
